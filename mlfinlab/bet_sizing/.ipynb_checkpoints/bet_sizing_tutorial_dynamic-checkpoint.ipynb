# %% [markdown]
# # `mlfinlab.bet_sizing` - Module Tutorial
# The following is a tutorial in how to apply the functions in the `mlfinlab.bet_sizing` module. The exercises from Chapter 10 are used as examples.

# %%
# imports
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns

from IPython.display import display
import datetime as dt

# mlfinlab imports
from mlfinlab.bet_sizing import bet_size_dynamic
from mlfinlab.bet_sizing.ch10_snippets import get_w, get_t_pos, limit_price, bet_size, inv_price
from mlfinlab.bet_sizing.ch10_snippets import get_w_power, get_t_pos_power, limit_price_power, bet_size_power, inv_price_power

# %% [markdown]
# ----
# #### Dynamic Bet Size example
# Randomly generate some samples for current position, maximum position, market price, forecast price, and supply some calibration parameters. While these values may not be completely realistic (especially when taken as a time series), they test operation of the dynamic bet size functions.

# %%
# setup parameters
np.random.seed(10)
sample_size = 1_000

# assign dates for index
start_date = dt.datetime(2000, 1, 1)  # starting at 01-JAN-2000
date_step = dt.timedelta(days=1)
dates = np.array([start_date + i*date_step for i in range(sample_size)])

curr_pos = pd.Series(data=np.random.uniform(80, 130, sample_size).astype(int), index=dates)
#curr_pos = 100
max_pos = pd.Series(data=np.array([135 for i in range(sample_size)]).astype(int), index=dates)
#max_pos = 135
market_price = pd.Series(data=np.random.uniform(75, 155, sample_size), index=dates)
#market_price = 201.5
forecast_price = pd.Series(data=np.random.uniform(70, 160, sample_size), index=dates)
#forecast_price = 197.45
cal_div = 10
cal_bet_size = 0.95
bet_function = 'sigmoid'

df_input = pd.concat([curr_pos, max_pos, market_price, forecast_price], axis=1)
df_input = df_input.rename(columns={0: 'pos',  # current position
                                    1: 'max_pos',  # maximum position
                                    2: 'm_p',  # market price
                                    3: 'f'})  # forecast price

display(df_input.head(5))

df_bets = bet_size_dynamic(curr_pos, max_pos, market_price, forecast_price, cal_div, cal_bet_size, bet_function)
display(df_bets.head(5))
# Out:
#             pos  max_pos         m_p           f
# 2000-01-01  118      135  102.866394  123.079981
# 2000-01-02   81      135  139.717029  139.611124
# 2000-01-03  111      135  111.770975  120.262382
# 2000-01-04  117      135  125.089944   86.670071
# 2000-01-05  104      135   91.291746  103.070211
#             bet_size  t_pos         l_p
# 2000-01-01  0.987036    133  120.213411
# 2000-01-02 -0.032204     -4    0.000000
# 2000-01-03  0.932574    125  117.726961
# 2000-01-04 -0.996361   -134    5.681977
# 2000-01-05  0.963200    130  100.570138

# %% [markdown]
# Combine the results into a single `DataFrame`. Note that some of the limit prices are either zero or `np.nan`, neither of which are realistic. The columns at the right end of the `DataFrame` explore some reasons as to why the limit prices may not be practical values.

# %%
df2 = pd.concat([df_input, df_bets], axis=1)
df2['sign(t_pos - pos)'] = df2.apply(lambda x: np.sign(x.t_pos - x.pos), axis=1)
df2['t_pos == pos'] = df2.apply(lambda x: x.t_pos == x.pos, axis = 1)
df2['sum can exec'] = df2.apply(lambda x: abs(x.t_pos) - abs(x.pos + np.sign(x.t_pos-x.pos)) > 0, axis=1)
df2['sign(m_p - pos)'] = df2.apply(lambda x: np.sign(x.m_p - x.pos), axis=1)
df2['is l_p sensible'] = df2.apply(lambda x: x.m_p < x.l_p < x.f if x.bet_size > 0 else np.nan, axis=1)
display(df2.head(35))
# Out:
#             pos  max_pos         m_p           f  bet_size  t_pos         l_p  \
# 2000-01-01  118      135  102.866394  123.079981  0.987036    133  120.213411
# 2000-01-02   81      135  139.717029  139.611124 -0.032204     -4    0.000000
# 2000-01-03  111      135  111.770975  120.262382  0.932574    125  117.726961
# 2000-01-04  117      135  125.089944   86.670071 -0.996361   -134    5.681977
# 2000-01-05  104      135   91.291746  103.070211  0.963200    130  100.570138
# 2000-01-06   91      135   82.494032  132.101356  0.997812    134  129.770719
# 2000-01-07   89      135  153.042077  139.583669 -0.971449   -131   26.237414
# 2000-01-08  118      135  104.387506  101.421284 -0.669971    -90    0.000000
# 2000-01-09   88      135  121.102717   85.382205 -0.995793   -134   17.237153
# 2000-01-10   84      135   94.674565   82.373162 -0.966108   -130   17.268069
# 2000-01-11  114      135  154.396696  129.768559 -0.991212   -133    9.775296
# 2000-01-12  127      135  120.301690  139.395846  0.985505    133  136.323950
# 2000-01-13   80      135  116.342916  159.658714  0.997133    134  157.530759
# 2000-01-14  105      135  145.514717  135.068808 -0.953893   -128   13.096750
# 2000-01-15  120      135   75.953072  138.315069  0.998614    134  135.380357
# 2000-01-16  110      135  133.419457   71.554071 -0.998592   -134    6.779679
# 2000-01-17  116      135  100.502375  114.331756  0.972899    131  111.555360
# 2000-01-18   94      135  127.000206  131.289958  0.793782    107  129.447704
# 2000-01-19  125      135  141.025769   73.669009 -0.998812   -134    2.457208
# 2000-01-20  115      135  109.739041   97.047479 -0.968063   -130    5.779815
# 2000-01-21  107      135   87.547095  114.237956  0.992503    133  111.609114
# 2000-01-22   87      135  113.188792  133.059620  0.986594    133  130.825740
# 2000-01-23   98      135  101.400630   70.241877 -0.994482   -134   10.529691
# 2000-01-24  113      135   94.243313   76.051843 -0.984066   -132    5.692707
# 2000-01-25  102      135  123.636585   93.114395 -0.994252   -134   12.291701
# 2000-01-26  101      135   92.117969   95.295308  0.695029     93    0.000000
# 2000-01-27  110      135  113.694660   74.244326 -0.996547   -134    7.044294
# 2000-01-28  105      135  110.526286   79.463360 -0.994448   -134    9.335764
# 2000-01-29  112      135  104.183836   91.831591 -0.966373   -130    6.638528
# 2000-01-30  110      135  104.046725  157.492350  0.998114    134  154.777362
# 2000-01-31  120      135   92.123961  159.522936  0.998813    134  156.588224
# 2000-02-01  106      135  104.449563  127.838307  0.990269    133  125.230356
# 2000-02-02  125      135   87.336784  154.995764  0.998822    134  151.946682
# 2000-02-03   95      135  131.734941  157.657399  0.992057    133  155.271305
# 2000-02-04   84      135  140.965538  148.701959  0.920380    124  146.708483
#
#             sign(t_pos - pos)  t_pos == pos  sum can exec  sign(m_p - pos)  \
# 2000-01-01                1.0         False          True             -1.0
# 2000-01-02               -1.0         False         False              1.0
# 2000-01-03                1.0         False          True              1.0
# 2000-01-04               -1.0         False          True              1.0
# 2000-01-05                1.0         False          True             -1.0
# 2000-01-06                1.0         False          True             -1.0
# 2000-01-07               -1.0         False          True              1.0
# 2000-01-08               -1.0         False         False             -1.0
# 2000-01-09               -1.0         False          True              1.0
# 2000-01-10               -1.0         False          True              1.0
# 2000-01-11               -1.0         False          True              1.0
# 2000-01-12                1.0         False          True             -1.0
# 2000-01-13                1.0         False          True              1.0
# 2000-01-14               -1.0         False          True              1.0
# 2000-01-15                1.0         False          True             -1.0
# 2000-01-16               -1.0         False          True              1.0
# 2000-01-17                1.0         False          True             -1.0
# 2000-01-18                1.0         False          True              1.0
# 2000-01-19               -1.0         False          True              1.0
# 2000-01-20               -1.0         False          True             -1.0
# 2000-01-21                1.0         False          True             -1.0
# 2000-01-22                1.0         False          True              1.0
# 2000-01-23               -1.0         False          True              1.0
# 2000-01-24               -1.0         False          True             -1.0
# 2000-01-25               -1.0         False          True              1.0
# 2000-01-26               -1.0         False         False             -1.0
# 2000-01-27               -1.0         False          True              1.0
# 2000-01-28               -1.0         False          True              1.0
# 2000-01-29               -1.0         False          True             -1.0
# 2000-01-30                1.0         False          True             -1.0
# 2000-01-31                1.0         False          True             -1.0
# 2000-02-01                1.0         False          True             -1.0
# 2000-02-02                1.0         False          True             -1.0
# 2000-02-03                1.0         False          True              1.0
# 2000-02-04                1.0         False          True              1.0
#
#            is l_p sensible
# 2000-01-01            True
# 2000-01-02             NaN
# 2000-01-03            True
# 2000-01-04             NaN
# 2000-01-05            True
# 2000-01-06            True
# 2000-01-07             NaN
# 2000-01-08             NaN
# 2000-01-09             NaN
# 2000-01-10             NaN
# 2000-01-11             NaN
# 2000-01-12            True
# 2000-01-13            True
# 2000-01-14             NaN
# 2000-01-15            True
# 2000-01-16             NaN
# 2000-01-17            True
# 2000-01-18            True
# 2000-01-19             NaN
# 2000-01-20             NaN
# 2000-01-21            True
# 2000-01-22            True
# 2000-01-23             NaN
# 2000-01-24             NaN
# 2000-01-25             NaN
# 2000-01-26           False
# 2000-01-27             NaN
# 2000-01-28             NaN
# 2000-01-29             NaN
# 2000-01-30            True
# 2000-01-31            True
# 2000-02-01            True
# 2000-02-02            True
# 2000-02-03            True
# 2000-02-04            True

# %%
a, b, c, d = 1, 2, 3, 4
print(a,b,c,d)
for i in [a, b, c, d]:
    i = i*i
print(a,b,c,d)
# Out:
# 1 2 3 4
# 1 2 3 4

# %%
a = True
print(a)
# Out:
# True

# %%
a = a and False
print(a)
# Out:
# False

# %%
curr_pos.size
# Out:
# 1000

# %%
True and not False
# Out:
# True

# %%
d = {'a':1, 'b':2, 'c':3}
for i in d:
    print(i)
# Out:
# a
# b
# c

# %%
def square(n):
    return n*n

def cube(n):
    return n*n*n

def quart(n):
    return n*n*n*n

d_func = {'sq': square,
          'cu': cube,
          'qu': quart}

f = 'sq'
print({'sq': square, 'cu': cube, 'qu': quart}[f](4))
# Out:
# 16

# %%
m = 0.7
x = 4
f = 110.6

#w_param = get_w_power(x, m)
#print(f"w_param: {w_param}")

#inverted_price = inv_price_power(f, w_param, m)
#print(f"inverted_price: {inverted_price}")

#lim_price = limit_price_power(120, 110, f, w_param, 150)
#print(f"limit_price: {lim_price}")

print(f"bet size: {bet_size_power(0.4, x)}")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-0c88b18e7338> in <module>
#      12 #print(f"limit_price: {lim_price}")
#      13
# ---> 14 print(f"bet size: {bet_size_power(0.4, x)}")
#
# D:\GitProjects\mlfinlab\mlfinlab\bet_sizing\ch10_snippets.py in bet_size_power(w, x)
#     206     :return: (float) The bet size.
#     207     """
# --> 208     assert (-1 <= x <= 1), f"Price divergence must be between -1 and 1, inclusive. Found price divergence value: {x}"
#     209     if x == 0.0:
#     210         return 0.0
#
# AssertionError: Price divergence must be between -1 and 1, inclusive. Found price divergence value: 4

# %%
(-1 <= -0.3 <= 1)
# Out:
# True
